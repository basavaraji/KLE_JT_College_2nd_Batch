# %%
print("Hello World");
# Out:
# Hello World

# %% [markdown]
# Python Second Program

# %%
print("*"*3)
# Out:
# ***

# %%
print("*"*3, sep="\n")
# Out:
# ***

# %%
print("*\n"*3)
# Out:
# *
# *
# *

# %%
Name = "Basavaraj"
print(Name)
# Out:
# Basavaraj
